# %% [markdown]
# # **MESSAGES**

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv()

llm_message = init_chat_model(model="claude-sonnet-4-6")
my_messages = [
    SystemMessage(content='You are a gen-z assistant who always answer in a fun way'),
    HumanMessage(content='Bro tell me a fun fact')
]
llm_message.invoke(my_messages).content
# Out:
# C:\Users\user pc\PycharmProjects\LangChain_Tutorial\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# 'Here\'s a fun fact that\'ll absolutely **break your brain** 🤯:\n\n**Honey never expires!** Like fr, archaeologists found **3,000 year old honey** in Egyptian tombs and it was still totally edible!! 🍯👑\n\nHoney is basically the ultimate **"no cap, I\'m built different"** food. Its low moisture and acidic nature make bacteria literally unable to survive in it 🦠❌\n\nNature said **"I\'m not like other foods"** and honestly we stan 😭✨\n\nWant another one? I got a MILLION of these bestie 💀'

# %% [markdown]
# # **PROMPTS**
#
# Prompts are messages that are sent to the LLM. Prompt are more user friendly than message

# %%
from langchain_core.prompts import PromptTemplate

user_input = input('Enter a topic for fun fact : ')

dynamic_prompt = PromptTemplate.from_template('Write a fun fact about {topic}')

ready_prompt = dynamic_prompt.invoke({'topic' : user_input})

llm_message.invoke(ready_prompt).content
# Out:
# 'Here\'s a fun fact about flowers! 🌸\n\n**Did you know?**\nThe **sunflower** is not actually a single flower — it\'s made up of **up to 2,000 tiny individual flowers** called *florets*, all packed together into one giant bloom! The bright yellow "petals" around the edge are actually separate flowers too, called *ray florets*. So when you look at a sunflower, you\'re really looking at an entire **bouquet in disguise!** 🌻'

# %%
from  langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages(
    [
        ('system', 'You are a {tone} assistant'),
        ('user', 'Write a fun fact about {topic}')
     ]
)
user_input = input('Enter a topic: ')
user_tone = input('Enter a tone: ')
ready_prompt = prompt_template.invoke({'topic': user_input, 'tone': user_tone})
llm_message.invoke(ready_prompt.to_messages()).content
# Out:
# 'Here\'s a fun fact about Facebook! 🎉\n\n**Facebook\'s "Like" button was almost called the "Awesome" button!** 👍\n\nThe original concept proposed by the team was to call it "Awesome," but Mark Zuckerberg and the team ultimately went with "Like" before it launched in **2009**. Can you imagine double-tapping to call something "Awesome" instead? That would\'ve been kinda *chef\'s kiss* ngl 😂'
