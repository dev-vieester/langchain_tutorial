# %% [markdown]
# # **LLM CAL**

# %%
from langchain_anthropic import ChatAnthropic

llm_anthropic = ChatAnthropic(model="claude-sonnet-4-6", temperature=0)

llm_anthropic.invoke('Bro tell me fun fact').content
# Out:
# AIMessage(content="Here's a fun fact for you! 🎉\n\n**Octopuses have THREE hearts!** 🐙❤️❤️❤️\n\n- Two hearts pump blood to the gills\n- One heart pumps blood to the rest of the body\n- AND their blood is **blue** because it contains copper instead of iron!\n\nPretty wild, right? Want another fun fact? 😄", additional_kwargs={}, response_metadata={'id': 'msg_01Tp4uUyWUptp9G1Y23p4aci', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 14, 'output_tokens': 93, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--019cbc4b-9ad8-74d2-9ac8-a659d42f8ef8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 93, 'total_tokens': 107
# ...

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

load_dotenv()

if os.environ.get('ANTHROPIC_API_KEY'):
    print('Bro Api Key Exists!!!')
else:
    raise ValueError('ANTHROPIC_API_KEY not found')

llm_anthropic = init_chat_model(model="claude-sonnet-4-6")

llm_anthropic.invoke('Tell me a fun fact').content
# Out:
# Bro Api Key Exists!!!
# "Here's a fun fact:\n\n**Honey never spoils.** 🍯\n\nArchaeologists have found honey in ancient Egyptian tombs that is over **3,000 years old** — and it was still perfectly edible! Honey's low moisture content and natural acidity make it nearly impossible for bacteria to grow in it.\n\nWant to hear another one? 😄"
